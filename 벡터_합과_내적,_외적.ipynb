# %% [markdown]
# <a href="https://colab.research.google.com/github/dragon7268/physics/blob/20250331/%EB%B2%A1%ED%84%B0_%ED%95%A9%EA%B3%BC_%EB%82%B4%EC%A0%81%2C_%EC%99%B8%EC%A0%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))

y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x 성분을 입력하세요: "))

y2 = float(input("두 번째 벡터의 y 성분을 입력하세요: "))

sum_x = x1 + x2

sum_y = y1 + y2

dot_product = x1 * x2 + y1 * y2

cross_product = x1 * y2 - y1 * x2

print("\n벡터 1:", x1, "i +", y1, "j")
print("벡터 2:", x2, "i +", y2, "j")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product)
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 50
# 첫 번째 벡터의 y 성분을 입력하세요: 60
# 두 번째 벡터의 x 성분을 입력하세요: 70
# 두 번째 벡터의 y 성분을 입력하세요: 80
#
# 벡터 1: 50.0 i + 60.0 j
# 벡터 2: 70.0 i + 80.0 j
#
# 벡터의 합: 120.0 i + 140.0 j
# 벡터의 내적: 8300.0
# 벡터의 외적: -200.0

# %%
x1 = float(input("첫 번째 벡터의 x 성분을 입력하세요: "))
y1 = float(input("첫 번째 벡터의 y 성분을 입력하세요: "))
z1 = float(input("첫 번째 벡터의 z4 성분을 입력하세요: "))

x2 = float(input("두 번째 벡터의 x2 성분을 입력하세요: "))
y2 = float(input("두 번째 벡터의 y2 성분을 입력하세요: "))
z2 = float(input("두 번째 벡터의 z2 성분을 입력하세요: "))

sum_x = x1 + x2
sum_y = y1 + y2
sum_z = z1 + z2

dot_product = x1 * x2 + y1 * y2 + z1 * z2

cross_product_x = y1 * z2 - z1 * y2
cross_product_y = z1 * x2 - x1 * z2
cross_product_z = x1 * y2 - y1 * x2

print("\n벡터 1:", x1, "i +", y1, "j +", z1, "k")
print("벡터 2:", x2, "i +", y2, "j +", z2, "k")

print("\n벡터의 합:", sum_x, "i +", sum_y, "j +", sum_z, "k")
print("벡터의 내적:", dot_product)
print("벡터의 외적:", cross_product_x, "i +", cross_product_y, "j +", cross_product_z, "k")
# Out:
# 첫 번째 벡터의 x 성분을 입력하세요: 40
# 첫 번째 벡터의 y 성분을 입력하세요: 50
# 첫 번째 벡터의 z4 성분을 입력하세요: 60
# 두 번째 벡터의 x2 성분을 입력하세요: 70
# 두 번째 벡터의 y2 성분을 입력하세요: 80
# 두 번째 벡터의 z2 성분을 입력하세요: 90
#
# 벡터 1: 40.0 i + 50.0 j + 60.0 k
# 벡터 2: 70.0 i + 80.0 j + 90.0 k
#
# 벡터의 합: 110.0 i + 130.0 j + 150.0 k
# 벡터의 내적: 12200.0
# 벡터의 외적: -300.0 i + 600.0 j + -300.0 k

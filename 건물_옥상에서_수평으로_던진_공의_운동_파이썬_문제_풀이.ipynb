# %% [markdown]
# <a href="https://colab.research.google.com/github/dragon7268/physics/blob/20250406/%EA%B1%B4%EB%AC%BC_%EC%98%A5%EC%83%81%EC%97%90%EC%84%9C_%EC%88%98%ED%8F%89%EC%9C%BC%EB%A1%9C_%EB%8D%98%EC%A7%84_%EA%B3%B5%EC%9D%98_%EC%9A%B4%EB%8F%99_%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EB%AC%B8%EC%A0%9C_%ED%92%80%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
# 사용자 입력

t = float(input("공이 떨어지기까지 걸린 시간 (초)을 입력하세요 (예: 2): "))

x = float(input("수평 거리 (m)를 입력하세요 (예: 20): "))
# Out:
# 공이 떨어지기까지 걸린 시간 (초)을 입력하세요 (예: 2): 2
# 수평 거리 (m)를 입력하세요 (예: 20): 20

# %%
# 중력 가속도

g = 9.81  # m/s^2

# %%
# 초기 위치와 수직 방향 속도
y0 = 0
v0y = 0

# %%
# a) 공의 처음속도 (수평속도)

v0x = x/t

# %%
# b) 옥상의 높이 (자유낙하 공식 사용)

y = y0 + v0y*t + 1/2*g*t*t

# %%
# c) 공이 지면에 닿을 때 속도

vx = v0x

vy = v0y + g * t

# %%
# 최종 속도 크기

v = math.sqrt(vx*vx + vy*vy)

# %%
# 최종 속도 방향 (아래로 향한 각도, 단위: 도)

theta_rad = math.atan2(vy, vx)

theta_deg = math.degrees(theta_rad)

# %%
# 결과 출력

print(f"\n[결과]")

print(f"a) 공의 처음속도 크기: {v0:.2f} m/s")

print(f"b) 건물 높이: {y:.2f} m")

print(f"c) 충돌 순간 속도 크기: {v:.2f} m/s")

print(f"   충돌 순간 속도 방향 (수평선과 이루는 각도): {theta_deg:.2f}도")
# Out:
# [결과]
# a) 공의 처음속도 크기: 10.00 m/s
# b) 건물 높이: 19.62 m
# c) 충돌 순간 속도 크기: 22.02 m/s
#    충돌 순간 속도 방향 (수평선과 이루는 각도): 62.99도

# %% [markdown]
# <a href="https://colab.research.google.com/github/dragon7268/physics/blob/20250302/Trigonometric_functions_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math #수학 함수를 사용하기 위해서 라이브러리 추가

# %% [markdown]
# 호도법
# 아래 링크 참조하세요

# %%
angle_degree = 30
angle_radian = angle_degree * math.pi / 180
print("angle_radian : ",angle_radian)
# Out:
# angle_radian :  0.5235987755982988

# %%
math.cos(angle_radian)
# Out:
# 0.8660254037844387

# %%
math.sin(angle_radian)
# Out:
# 0.49999999999999994

# %%
math.tan(angle_raidan)
# Out:
# 0.5773502691896257

# %% [markdown]
# 직교좌표를 극좌표로 변환

# %%
x,y = 1.0, 2.0

# %%
r = math.sqrt(x**2 + y**2)
theta_raidan = math.atan2(y,x)
print(r,theta_raidan)
# Out:
# 2.23606797749979 1.1071487177940904

# %% [markdown]
# 극좌표를 직교좌표로 변환

# %%
r, angle = 10,30

# %%
theta_radian = math.radians(angle)

x = r*math.cos(theta_radian)
y=  r*math.sin(theta_radian)

print(x,y)
# Out:
# 8.660254037844387 4.999999999999999
